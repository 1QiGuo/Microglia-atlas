# %% [markdown]
# ## Nested clustering of cells in the SCA, and cluster differential expression analysis (DEA)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# In this notebook we perform multi-level clustering of the cells in the SCA. We start with coarse-resolution clustering, and then re-cluster the resulting clusters by first re-calculating the nearest-neighbor graph and then clustering each cluster, with a finer resolution. For the final HLCA, we also calculate marker genes for every cluster. These will be used during manual annotation of the SCA.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scanpy.external as sce
import sys
import os

sys.path.append("/fs/ess/PAS1475/guoqi/sci_atlas/Lung_splitdata/HLCA_reproducibility/scripts")
import nested_clustering
import analysis

# %%
path_SCA = "/fs/ess/PAS1475/guoqi/sci_atlas/Merge_health/health_scanvi_1117_sepleu.h5ad"
dir_benchmarking_cluster_output = "/fs/ess/PAS1475/guoqi/sci_atlas/Merge_health/Merge_Dec/Clustering/Benchmark/"
dir_SCA_cluster_output="/fs/ess/PAS1475/guoqi/sci_atlas/Merge_health/Merge_Dec/Clustering/"

# %%
dataset_name = "SCA"  # final, full HLCA

# %% [markdown]
# Set number of cluster levels (we used 3 for benchmark methods and for final atlas, and 4 for the full SCA)

# %%
number_of_clust_levels = 4

# %%
print("Dataset name:", dataset_name)
if dataset_name == "scanvi":
    # load dataset
    adata = sc.read(os.path.join(dir_benchmarking_res, "unscaled/hvg/scanvi.h5ad"))
    # specify which obsm to use for calculating neighbor graph
    use_rep = "X_emb"
    # specify whether or not to re-calculate the PCA for subsets of the object
    redo_pca = False
elif dataset_name == "seuratrpca":
    adata = sc.read(
        os.path.join(dir_benchmarking_res, "unscaled/hvg/R/seuratrpca.h5ad")
    )
    sc.tl.pca(adata)
    use_rep = "X_pca"
    redo_pca = True
elif dataset_name == "harmony":
    adata = sc.read(os.path.join(dir_bencmarking_res, "scaled/hvg/R/harmony.h5ad"))
    adata.obsm["X_pca"] = adata.obsm["X_emb"]
    use_rep = "X_emb"
    redo_pca = False
elif dataset_name == "SCA":
    adata = sc.read(path_SCA)
    use_rep = "X_scANVI"
    redo_pca = False
# Out:
# Dataset name: SCA

# %%
adata
use_rep = "X_scANVI"

# %%
for clustering_level in range(1, number_of_clust_levels + 1):
    print("clustering level:", clustering_level, "...")
    if clustering_level == 1:
        # skip for re-run
        cluster_name = "leiden_1"
        # first clustering is not nested, so use normal function:
        sc.pp.neighbors(adata, n_neighbors=30, use_rep=use_rep)
        sc.tl.leiden(adata, resolution=0.01, key_added=cluster_name)
    else:
        previous_clustering = "leiden_" + str(clustering_level - 1)
        cluster_name = "leiden_" + str(clustering_level)
        #         perform nested clustering
        #         set parameters:
        res = 0.2
        if clustering_level == 2:
            k = 30
            min_cluster_size = 50
        elif clustering_level == 3:
            k = 15
            min_cluster_size = 30
        elif clustering_level == 4:
            k = 10
            min_cluster_size = 10

        adata = nested_clustering.add_nested_clustering_blind(
            adata,
            previous_clustering,
            cluster_name,
            use_rep=use_rep,
            cluster_alg="leiden",
            cluster_k=k,
            cluster_res=res,
            min_cluster_size=min_cluster_size,
            redo_pca=redo_pca,  # SET THIS TO FALSE FOR SCANVI!!! OR OTHER EMBEDDING-OUTPUT METHODS!!!!!
        )
    # plot
    if "X_umap" in adata.obsm.keys():
        sc.pl.umap(adata, color=cluster_name)
    # store clustering:
    cluster_df = pd.DataFrame(adata.obs[cluster_name], index=adata.obs.index)
    # write to csv for benchmarking data:
    if dataset_name in ["harmony","scanvi","seuratrpca"]:
        cluster_df.to_csv(
            os.path.join(dir_benchmarking_cluster_output, f"{dataset_name}/{dataset_name}_{cluster_name}_cluster_assignment.csv")
        )
    # If wanted/needed, for final HLCA:
    if dataset_name == "SCA":
        # store cluster assignments:
        cluster_df.to_csv(
            os.path.join(dir_SCA_cluster_output, f"LCA_{cluster_name}_cluster_assignment.csv")
        )
        # calculate marker genes with respect to all other clusters, and with respect to sister clusters (i.e. other cluster from the same parent cluster):
        for marker_ref in ["sisters", "all"]:
            marker_gene_df = nested_clustering.get_cluster_markers(
                adata=adata,
                cluster_label=cluster_name,
                marker_ref=marker_ref,
                ngenes=100,
            )
            # and store:
            marker_gene_df.to_csv(
                os.path.join(dir_SCA_cluster_output, f"LCA_{cluster_name}_marker_genes_versus_{marker_ref}.csv")
            )
# Out:
# clustering level: 1 ...
# Doing one versus sisters differential expression analysis.
# ranking genes for parent group all
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# Doing one versus all differential expression analysis.
# ranking genes for parent group all
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# clustering level: 2 ...
# Not re-doing pca before nested clustering iterations!
# Cluster: 0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Doing one versus sisters differential expression analysis.
# ranking genes for parent group 0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# Doing one versus all differential expression analysis.
# ranking genes for parent group 0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# clustering level: 3 ...
# Not re-doing pca before nested clustering iterations!
# Cluster: 0.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 0.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 0.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 0.3
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 0.4
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 0.5
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 0.6
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.10
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.3
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.4
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.5
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.6
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.7
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.8
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.9
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.3
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.4
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Doing one versus sisters differential expression analysis.
# ranking genes for parent group 0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.5
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.6
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.10
# Cluster 1.10 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.5
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.8
# Cluster 1.8 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.9
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# Doing one versus all differential expression analysis.
# ranking genes for parent group 0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.5
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.6
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.10
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.5
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.8
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.9
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 1.9.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.0.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.0.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.1.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.1.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.2.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.2.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 2.2.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.0.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.0.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.0.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.1.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.1.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.2.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.2.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.3.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.3.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.3.2
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.4.0
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Cluster: 3.4.1
# reclustering...
#
# calculating 30 nearest neighbors
# using rep: X_scANVI
# clustering
# Doing one versus sisters differential expression analysis.
# ranking genes for parent group 0.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.0.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.1.0
# Cluster 0.1.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.3.0
# Cluster 0.3.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.3.1
# Cluster 0.3.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.4.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.3
# Cluster 0.4.3 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.4.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.5
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.5.0
# Cluster 0.5.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.5.1
# Cluster 0.5.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.6.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.6.1
# Cluster 0.6.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 0.6.2
# Cluster 0.6.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0.2
# Cluster 1.0.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.1.0
# Cluster 1.1.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.1.1
# Cluster 1.1.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.1.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.10.0
# Cluster 1.10.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.2.1
# Cluster 1.2.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.3
# Cluster 1.3.3 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.4.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.5.0
# Cluster 1.5.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.5.1
# Cluster 1.5.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.6.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6.1
# Cluster 1.6.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.6.2
# Cluster 1.6.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.6.3
# Cluster 1.6.3 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.7.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7.1
# Cluster 1.7.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.7.2
# Cluster 1.7.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.7.3
# Cluster 1.7.3 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.7.4
# Cluster 1.7.4 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.8.0
# Cluster 1.8.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 1.9.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.9.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.0.0
# Cluster 2.0.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 2.0.1
# Cluster 2.0.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 2.1.0
# Cluster 2.1.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 2.1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2.0
# Cluster 2.2.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 2.2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2.2
# Cluster 2.2.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0.2
# Cluster 3.0.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.1.1
# Cluster 3.1.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.2.0
# Cluster 3.2.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.2.1
# Cluster 3.2.1 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.3.0
# Cluster 3.3.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.3.2
# Cluster 3.3.2 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.4.0
# Cluster 3.4.0 has only one subcluster. Skipping DEA for this parent.
# ranking genes for parent group 3.4.1
# Cluster 3.4.1 has only one subcluster. Skipping DEA for this parent.
# Doing one versus all differential expression analysis.
# ranking genes for parent group 0.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.0.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.3.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.4.5
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.5.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.5.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.6.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.6.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 0.6.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.0.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.1.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.10.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.3.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.4.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.5.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.5.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.6.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7.3
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.7.4
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.8.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.9.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 1.9.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 2.2.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.0.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.1.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.1.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.2.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.2.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.3.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.3.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.3.2
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.4.0
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# ranking genes for parent group 3.4.1
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.

# %%
cluster_name = "leiden_1"
# first clustering is not nested, so use normal function:
sc.pp.neighbors(adata, n_neighbors=30, use_rep=use_rep)
sc.tl.leiden(adata, resolution=0.01, key_added=cluster_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 cluster_name = "leiden_1"
#       2 # first clustering is not nested, so use normal function:
# ----> 3 sc.pp.neighbors(adata, n_neighbors=30, use_rep=use_rep)
#       4 sc.tl.leiden(adata, resolution=0.01, key_added=cluster_name)
#
# File ~/.conda/envs/scvi-env-0926/lib/python3.9/site-packages/scanpy/neighbors/__init__.py:148, in neighbors(adata, n_neighbors, n_pcs, use_rep, knn, random_state, method, metric, metric_kwds, key_added, copy)
#     146     adata._init_as_actual(adata.copy())
#     147 neighbors = Neighbors(adata)
# --> 148 neighbors.compute_neighbors(
#     149     n_neighbors=n_neighbors,
#     150     knn=knn,
#     151     n_pcs=n_pcs,
#     152     use_rep=use_rep,
#     153     method=method,
#     154     metric=metric,
#     155     metric_kwds=metric_kwds,
#     156     random_state=random_state,
#     157 )
#     159 if key_added is None:
#     160     key_added = 'neighbors'
#
# File ~/.conda/envs/scvi-env-0926/lib/python3.9/site-packages/scanpy/neighbors/__init__.py:780, in Neighbors.compute_neighbors(self, n_neighbors, knn, n_pcs, use_rep, method, random_state, write_knn_indices, metric, metric_kwds)
#     778 self.n_neighbors = n_neighbors
#     779 self.knn = knn
# --> 780 X = _choose_representation(self._adata, use_rep=use_rep, n_pcs=n_pcs)
#     781 # neighbor search
#     782 use_dense_distances = (metric == 'euclidean' and X.shape[0] < 8192) or not knn
#
# File ~/.conda/envs/scvi-env-0926/lib/python3.9/site-packages/scanpy/tools/_utils.py:64, in _choose_representation(adata, use_rep, n_pcs, silent)
#      62         X = adata.X
#      63     else:
# ---> 64         raise ValueError(
#      65             'Did not find {} in `.obsm.keys()`. '
#      66             'You need to compute it first.'.format(use_rep)
#      67         )
#      68 settings.verbosity = verbosity  # resetting verbosity
#      69 return X
#
# ValueError: Did not find X_scanvi_emb in `.obsm.keys()`. You need to compute it first.

# %%
adata.obsm["X_scANVI"]
# Out:
# array([[ 4.4126093e-02,  3.3352774e-01, -1.1815947e-01, ...,
#         -2.2312836e-01, -3.4999669e-02, -1.2129725e+00],
#        [-3.4622282e-01, -9.1891211e-01, -1.2108517e+00, ...,
#         -5.7857841e-01, -2.5263126e+00,  1.0947158e+00],
#        [-3.7217098e-01,  3.5347658e-01,  1.0170716e-01, ...,
#         -6.3096121e-02,  4.4821414e-01, -7.4611187e-01],
#        ...,
#        [-6.6431171e-01,  4.6551228e-05,  9.0643823e-02, ...,
#         -1.8450685e-01,  4.2656699e-01,  1.0230446e+00],
#        [ 1.4800693e+00,  2.8973323e-01,  3.5206327e-01, ...,
#         -7.8803003e-02,  7.3168504e-01, -6.3591421e-01],
#        [ 4.3472809e-01,  9.1349244e-01,  6.6058671e-01, ...,
#         -7.1263915e-01,  7.3647857e-02, -1.6532801e+00]], dtype=float32)

# %%
use_rep
# Out:
# 'X_scanvi_emb'
